# %% [markdown]
# # Notes

# %% [markdown]
# Place to place all notes with .md capabilities and $\LaTeX$
#
# previous notes were dotted throughout ipynbs and comments

# %% [markdown]
# ### 03/01/22
#
# sigma = bg + (peak)/( 1 + (r/r_c)^alpha) scale background by half the peak, etc.
# modify the king profile rt-> inf
# add free power and constant background
# total mass from 100 to 600 myr for pop2
# increase radius
# multiplot, rotationnot zoomed in.
#
# set to 1.5bg =  bg + (peak)/( 1 + (r/r_c)^alpha)
# $$  1.5\Sigma_{bg} = \Sigma_{bg} + \frac{\Sigma_0}{1 + (r/r_c)^{\alpha}} $$
#
# ### play with threshold
# #count mass up to the radius
# #mass is 2pi r_core^2 sigma_peak ln(rt/rc) from core radius out.
# ### Mcore = pi r_core^2 sigma_peak
# ### integrate sigma
# as as function of trunc radius

# %% [markdown]
# $$ \int \Sigma = \Sigma_{bg} + \frac{\Sigma_0}{1 + (r/r_c)^{\alpha}} $$

# %% [markdown]
# ### 03/29/22
#
# Notes
#
# + **request for more kSU ~ 300**
# + bubble plot: age of formation for star clusters instead, fills in as a function of time
# + mass function at a given snapshot
# + try to track the cluster via star IDs.
# - if the cluster has ~50/50 starslabel it as merger
# + *use truncation mass instead of total mass; if trunc fit doesn't make sense, get the total mass up to the radius*
# + *change thresholds for the profiler*
# + change from 10 pc uniform radius to 20 pc
# + sample data for fittig to prevent failure. (slice or otherwise)

# %% [markdown]
# ### 4/05/22
#
# add age distribution for profiler.
#
# increase center threshold
#
# line of sight filter
#
# relative maxima in 3d.
#
# everything in 3d.
#
# look up z.
#
# fstar =.35 movie
#
# parallelize python.

# %% [markdown]
# ### 4/19/22
# - run in through the profiler and use the centers in 3d to mask it out
# - 3d centers, mask, and then project them afterwards again.
# - for the two different simulations, number of gc as a function of time.
# - Mass in gc as a function of time.
# - mass in stars a function of time.
# - this gives the diffused mass.
# - temperature when the feed back is the most. ~10^4

# %% [markdown]
# ### 05/03/22
#
# -  linking length
# - ages within cluster
# - raise to alpha entire denominator?
# - mid july three weeks.
# - write stuff down for the paper.
# - write down what worked at the end.
# - fitting formulas.

# %% [markdown]
# ### 05/10/22
# - double check if the profiler number is less than or equal to the psc and sfc at that time
# - profiler ot particles beloning to a cluster only

# %% [markdown]
# ### 05/24/22
# - can make profiles for the entire galaxy
# - ~~mask out stars in clusters and not in clusters, use id of stars~~
# - ~~plot them or profile them.~~
# - ~~profile but with given star masked.~~
# - ~~trust fof for now, 20 pc overcounts~~
# - science plots
#     - ~~mass function over time~~
#     - ~~bound unbounds over time~~
#     - ~~mass function on a given snapshot~~
#     - histogram of ages for those with massive population of clusters.
#     - profiles of galaxy outisde of clusters
# - ~~important params~~
#     - r core
#     - $\alpha$
#     - $\Sigma_0$
#     - half-mass/ half-light
#     - core is like quarter mass
# - paper
#     - first simulation of bulg-less, diskless galaxy
#     - star cluster results
#     - destruction
#     - morphology of star distributions
#     - diffuse, low brightness

# %% [markdown]
# ### 06/08/22
# - bubble plot
# - field stars
#     - profile
#     - spherical profile: rotate
#     - density profile
#     - (0,0) center is ok
# - ~~luminosity over time~~
#     - ~~track of total gc luuminosity~~
#     - ~~total field lum.~~
#     - ~~core mass not in final time series plot~~
#     - ~~look up table implementation, they fade.~~
# - ~~dips in the time series~~
#     - ~~noise?~~
#     - ~~full run~~
#
# - ~~fof top gc_profiler ratio, log scale~~
#     - ~~bound to field stars~~
# - mass functions
#     - ~~log norm, lin y log x~~
#     - gaussian imf
#         - fit
#     - ~~compare the mass function to nearest imf by filtering logSFC~~
#         - how does the imf evolve with time?
#     - big one, IDENTIFY it see how metaalicity evolves
#         - age of stars to it
#         - get picked up and then disappears for the halo finder
#     - age of stars belonging to it.
#     - double check normalization
# - 0.35 plots
# - ROCKSTAR FOR MERGERS and Centers?
# - science
#     - core mass seems ot be a 1/3 or 1/2 multiple of total
#     - maybe, field stars old, those that are tidally expelled from bound stars
#     - so the field is old low lum stars
#     - luminosity is faily constant for the first ~2myr
#     - feedback at work for half effieciency. Theoretically more mass in stars by definition of the efficiency
#     - $SFE = M_{{gas}}/(M_{gas} + M_{*}) $

# %% [markdown]
# ### 06/21/22
# - ~~bubble plot~~
# - ~~remove "in GCs"~~
# - ~~multiply mass m_sfc with 35% maybe, or divide~~
# - ~~compate mc imf with mass star mass in mc imf~~
# - ~~look at the ~10^5 object (0.70)and see ages in it in a histogram~~
# - ~~gaussian fitting~~
# - ~~try FOF mass functions instead of profiles, more resistant to no profile snapshots.~~
# - ~~caption for the figures~~
# - profile master plots
# - ~~track 35% GC~~
#     - how the profile evolves over time.
#     - Using ID of star,
#     - try to find gc where it belongs over time
#     - look at process by which it is destroyed
#
# #### science
# - Note, same behavior for both efficiencues as long as $m_{*}$ is increasing rapidly.
#     - star forming in bound
#     - When not forming, star clusters disintigrate less quickly for 70%
#     - 35% has more fragile star clusters
#     - it appears that efficiency determines rate of disintigration as wello
# - Two ideas for means of evaporation.
#     - inter-cluster tidal effects
#     - internal dynamics, like 2-body relaxation.
#         - $t_{relax} \approx \left(\frac{R^3}{GM}\right)^{1/2} \frac{N}{8 \ln N}$
#         - glob clusters can relax, galaxies are colisionles
# - 35% star clusters are less dense
# - there is a low mass tail for the mass functions
# - 70% there are enough massive objects that grow
# - 35% efficiency can't form massive (afew 1000 or less)
#     - 800 solar mass would be destroyed
#     - core collapse in 35%
#     - factor of 10 orders of magnitude in radius.
# - master profiles should be included.
# - Two body relaxation is the main process, guess.
# - when the luminosity in the galaxy is large, the fraction of light coming from gc should be near 100%
# - If we observe a galaxy, it will be at starburst, in which we will predominnatly see GCs.
#     - there is a luminosity cut. If there is light, we ewill see it in GCs.
#     - even fro 0.35, not yet evaporated.
# - Run, N grid cells,
# - kazu might be able to help,
# - but, delete snapshot and rerun asking for more gigs per core,
#     -  6 GiB of RAM per core

# %% [markdown]
# ### 06/28/22
# - ~~double check half light and half mass~~
# - ~~power law fitting for mass func~~
# - dynamical friction causes small GCs to sink to the galaxy
#     - causing them to be smaller and smaller at a faster rate
# - for the big central GC for 0.70
#     - all formed at the same time
#     - most massive cluster has one star population, but
#     - different substrucutre
#     - but they are grtavitationally bound to each other.
#     - MCs form in a complex, but immediately gravitate toward another
# - GCs more massive than clouds
# - $SFE = M_{*} / M_{gas}$ but in general $SFE =  M_{*} / M_{gas} +M_{*}  $, all gas are present at birth, t=0
# - caption figures, methodology, not worry abt physics yet.
# - intepretation can be included
# - smaller efficiency
#      - star cluster mass function some slope power law, ~1
#      - slight truncation might be due to poison noise
#      - but there appears to be a systematic shift in the efficieny, these are stripped due to less boundness.
# - mass functions just need latest for paper.

# %% [markdown]
# ### 07/12/22
# - ~~Mass func~~
#     - ~~reformat~~
#     - ~~slope is not valuable~~
#     - ~~cut off mass is more descriptive~~
#     - ~~exp cutoff~~
#     - ~~lognormal, gaussian,~~
#     - ~~bimodal for 70%~~
# - ~~surface luminosity~~
#     - ~~normalize by area~~
#     - ~~separate fig? label with R (pc)~~
#     - ~~per parsec~~
#     - ~~maybe magnitude, luminosity for now~~
# - ~~metalicity dist for gcs, tracking and lookup table.~~
# - ~~bubble plot~~
# - ~~projden time series~~
# - ~~light time series~~
# - ~~gc to SFC figure out mass ratio since we know their origins~~
# - ~~metallicity of clsuters~~
#
# - gc profiles
#     - ~~pattern in params, trends in core mass, core radius, alpha, metallicity (bubble plot)~~
#     - maybe core radii histogram
#     - ~~profile over time for a gc, pick one~~
#     - fitting population
#     - ~~pick good gc to track over time.~~
#     - explain everything in text
# - science
#     - light is motly from BSC
#     - no disk or bulge
#     - destroyed intial clusters turn into diffuse light in galaxy
#     - steep alpha, core dominated
#     - spell things out.
#     - luminosity instantaneous burst
#     - starburst 99
