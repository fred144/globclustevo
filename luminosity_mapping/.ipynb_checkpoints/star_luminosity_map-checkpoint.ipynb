# %% [markdown]
# Attributing Star Luminosities

# %%
import numpy as np
import os
import yt
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt 
import pandas as pd

# %%
pop_2_data = np.loadtxt(r"star_positions_out_00400.txt") 
birth_epochs = pop_2_data[:,0] *1e6 
# rounding it to the nearest 1e6 years for now, need to revisit how the ages are convereted
ages = np.round(pop_2_data[:,1], 0) *1e6 
ages [ages == 0] = np.nan
x_pos = pop_2_data[:,2]
y_pos = pop_2_data[:,3] 
z_pos = pop_2_data[:,4]
xlim = -125, 125
ylim = -125, 125
print(np.min(ages))
# Out:
# nan

# %% [markdown]
# ### Just doing raw counts

# %%
plt.figure(figsize = (10,10)) 

plt.scatter(x_pos, y_pos, s=1, c='tab:red', alpha=.2, label='t = 458.34 ')
plt.xlim(xlim)
plt.ylim(ylim)
plt.title("Pop II Stars Postions | Snapshot 400")
plt.xlabel("x (pc)")
plt.ylabel("y (pc)")
plt.legend()

# %%
plt.figure(figsize = (12,10), )
log_scale = plt.hexbin(x_pos, y_pos, gridsize=1000, cmap='inferno', bins='log', extent=[-200, 200, -200, 200])
plt.xlim(-125, 125)
plt.ylim(-125, 125)
plt.title("Pop II Stars Snapshot 400")
plt.xlabel("x (pc)")
plt.ylabel("y (pc)")
plt.colorbar(log_scale, label='log Counts', pad = 0)

# %%
pixel_values = log_scale.get_array() 
positons = log_scale.get_offsets() 
x = positons[:,0]
y = positons[:,1]

# %%
plt.figure(figsize = (12,10), )
plt.hexbin(x , y, pixel_values, cmap='inferno', bins='log', gridsize=1000)
plt.xlim(-125, 125)
plt.ylim(-125, 125)
# Out:
# (-125.0, 125.0)

# %%
print(x.size)
# Out:
# 1155578

# %%
df = pd.read_csv('https://www.stsci.edu/science/starburst99/data/l1500_inst_e.dat', delim_whitespace=True, header=None)
data = df.to_numpy().astype(float)
time = data[:,0]
lum = data[:,2]

# %%
def power_law(time, a, exp):
    lum = a * time**exp

    return lum

# %%
plt.figure(figsize = (16,8), )
plt.subplot(1, 2, 1)
plt.plot(time, 10**lum, label='M_upper = 100 msun  \nalpha=3.3')
mask = time > 6.5e6
par, cov = curve_fit(power_law, time, lum) 
plt.plot(time, 10**power_law(time, *par), label = r'L = {:.2f}t*exp({:.2f})'.format(par[0], par[1]))
stellar_lums = 10**power_law(ages,*par ) 
mask = stellar_lums < 1e40
ages= ages[mask]
stellar_lums = stellar_lums[mask]
plt.scatter(ages, stellar_lums, s= 5, alpha = .3, c='tab:red', label='Pop II Ages')
plt.xlim(1e6,1e9)
plt.xscale('log')
plt.yscale('log')
plt.title("Monochromatic luminosity at 1500 Å z = 0.001")
plt.xlabel("Time (yr)")
plt.ylabel("Luminosity (erg/s/Å)")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(time, 10**lum, label='M_upper = 100 msun  \nalpha=3.3')
plt.plot(time, 10**(power_law(time, *par)), label = r'L = {:.2f}t*exp({:.2f})'.format(par[0], par[1]))

stellar_lums = 10**(power_law(ages,*par ))

plt.scatter(ages, stellar_lums, s= 5, alpha = .3, c='tab:red', label='Pop II Ag')
#plt.xlim(np.min(ages),np.max(ages))
#plt.ylim(np.min(stellar_lums), np.max(stellar_lums) )

plt.xscale('log')
plt.yscale('log')
plt.title("Monochromatic luminosity at 1500 Å z = 0.001")
plt.xlabel("Time (yr)")
plt.ylabel("Luminosity (erg/s/Å)")
plt.legend()
# Out:
# C:\Users\1.44\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in less

# %% [markdown]
# ### The ages are not yet discreet enough to prevent small values from happening (just formed recently), so the lminosities can get quite high.

# %%
plt.figure(figsize = (12,10), )
print(x_pos.size,y_pos.size,stellar_lums.size )
test = plt.hexbin(x_pos[mask], y_pos[mask], stellar_lums,
                  gridsize=1000, 
                  cmap='inferno',
                  bins='log', 
                  extent=[-200, 200, -200, 200], reduce_C_function=np.sum)
plt.colorbar(test, label='Monochromatic luminosity at 1500 Å z = 0.001', pad = 0)
plt.xlim(-100, 100)
plt.ylim(-100, 100)
# Out:
# 34861 34861 32569
# (-100.0, 100.0)

# %%
pixel_values = test.get_array() 
positons = test.get_offsets() 
testx = positons[:,0]
testy = positons[:,1]

# %%
print(x_pos.size)
# Out:
# 34861

# %%
np.min(stellar_lums)
# Out:
# 7.988939023876551e+36
